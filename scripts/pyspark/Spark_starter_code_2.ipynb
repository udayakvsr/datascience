# %% [markdown]
# # DS-610 Week 4 Homework: Structured APIs in Apache Spark
# This week we will work with the Veris Community Database (VCDB). This is a dataset in which each row represents a reported security incident. Each incident is time-stamped with the type of security attacks and the potential financial impact the reporting firm may have endured.
#
# This is an interesting dataset because it contains over 2,500 columns and the schema contains special characters such as '.' and whitespaces. We will practice more hands-on APIs to clean up the DataFrame for more interesting analysis.

# %% [markdown]
# ### Loading VCDB Data
# We will first load the VCDB data. It is recommended that you run this notebook on Saint Peters' Databricks environment as the data is over 100 MB. If you have a powerful desktop, you may also want to download the data onto your laptop.

# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StructType
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.sql.dataframe import DataFrame
sc = SparkContext.getOrCreate()
spark = SparkSession(sc)

# This is the default path to the data. If you are running locally, change the following line.
df = spark.read.format('csv').option('header', 'true').load('dbfs:/FileStore/shared_uploads/dlee5@saintpeters.edu/vcdb.csv')
#df = spark.read.format('csv').option('header', 'true').load('vcdb.csv')

# %% [markdown]
# ## Part 1: Warmup
# Let us check the column names and the number of columns and the number of rows. The column names is conveniently stored in `df.columns` as a Python list of column names. The number of rows can be obtained via the `count` method.
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.DataFrame.count.html

# %%
# Your code for Part 1 goes here.

print(len(df.columns))
print(df.columns)
df.count
# Out:
# 2550
# ['action.environmental.notes', 'action.environmental.variety.Deterioration', 'action.environmental.variety.Earthquake', 'action.environmental.variety.EMI', 'action.environmental.variety.ESD', 'action.environmental.variety.Fire', 'action.environmental.variety.Flood', 'action.environmental.variety.Hazmat', 'action.environmental.variety.Humidity', 'action.environmental.variety.Hurricane', 'action.environmental.variety.Ice', 'action.environmental.variety.Landslide', 'action.environmental.variety.Leak', 'action.environmental.variety.Lightning', 'action.environmental.variety.Meteorite', 'action.environmental.variety.Other', 'action.environmental.variety.Particulates', 'action.environmental.variety.Pathogen', 'action.environmental.variety.Power failure', 'action.environmental.variety.Temperature', 'action.environmental.variety.Tornado', 'action.environmental.variety.Tsunami', 'action.environmental.variety.Unknown', 'action.environmental.variety.Vermin', 'action.environmental.variety.Volcano', 'action.environmental.variety.Wind', 'action.error.notes', 'action.error.variety.Capacity shortage', 'action.error.variety.Classification error', 'action.error.variety.Data entry error', 'action.error.variety.Disposal error', 'action.error.variety.Gaffe', 'action.error.variety.Loss', 'action.error.variety.Maintenance error', 'action.error.variety.Malfunction', 'action.error.variety.Misconfiguration', 'action.error.variety.Misdelivery', 'action.error.variety.Misinformation', 'action.error.variety.Omission', 'action.error.variety.Other', 'action.error.variety.Physical accidents', 'action.error.variety.Programming error', 'action.error.variety.Publishing error', 'action.error.variety.Unknown', 'action.error.vector.Carelessness', 'action.error.vector.Inadequate personnel', 'action.error.vector.Inadequate processes', 'action.error.vector.Inadequate technology', 'action.error.vector.Other', 'action.error.vector.Random error', 'action.error.vector.Unknown', 'action.error.vector.Web application', 'action.hacking.cve', 'action.hacking.notes', 'action.hacking.result.Deploy payload', 'action.hacking.result.Elevate', 'action.hacking.result.Exfiltrate', 'action.hacking.result.Infiltrate', 'action.hacking.result.Lateral movement', 'action.hacking.result.NA', 'action.hacking.result.Other', 'action.hacking.result.Unknown', 'action.hacking.variety.Abuse of functionality', 'action.hacking.variety.Backdoor', 'action.hacking.variety.Brute force', 'action.hacking.variety.Buffer overflow', 'action.hacking.variety.Cache poisoning', 'action.hacking.variety.Cryptanalysis', 'action.hacking.variety.CSRF', 'action.hacking.variety.Disable controls', 'action.hacking.variety.DoS', 'action.hacking.variety.Evade Defenses', 'action.hacking.variety.Exploit misconfig', 'action.hacking.variety.Exploit vuln', 'action.hacking.variety.Forced browsing', 'action.hacking.variety.Format string attack', 'action.hacking.variety.Fuzz testing', 'action.hacking.variety.HTTP request smuggling', 'action.hacking.variety.HTTP request splitting', 'action.hacking.variety.HTTP response smuggling', 'action.hacking.variety.HTTP response splitting', 'action.hacking.variety.Insecure deserialization', 'action.hacking.variety.Integer overflows', 'action.hacking.variety.LDAP injection', 'action.hacking.variety.Mail command injection', 'action.hacking.variety.MitM', 'action.hacking.variety.Null byte injection', 'action.hacking.variety.Offline cracking', 'action.hacking.variety.OS commanding', 'action.hacking.variety.Other', 'action.hacking.variety.Pass-the-hash', 'action.hacking.variety.Path traversal', 'action.hacking.variety.Profile host', 'action.hacking.variety.Reverse engineering', 'action.hacking.variety.RFI', 'action.hacking.variety.Routing detour', 'action.hacking.variety.Scan network', 'action.hacking.variety.Session fixation', 'action.hacking.variety.Session prediction', 'action.hacking.variety.Session replay', 'action.hacking.variety.Soap array abuse', 'action.hacking.variety.Special element injec ...
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# OS', 'plus.asset_os.Windows', 'plus.asset_os.Windows Phone', 'plus.asset.total', 'plus.attack_difficulty_initial.High', 'plus.attack_difficulty_initial.Low', 'plus.attack_difficulty_initial.Moderate', 'plus.attack_difficulty_initial.NA', 'plus.attack_difficulty_initial.Other', 'plus.attack_difficulty_initial.Unknown', 'plus.attack_difficulty_initial.Very Low', 'plus.attack_difficulty_legacy.High', 'plus.attack_difficulty_legacy.Low', 'plus.attack_difficulty_legacy.Moderate', 'plus.attack_difficulty_legacy.NA', 'plus.attack_difficulty_legacy.Other', 'plus.attack_difficulty_legacy.Unknown', 'plus.attack_difficulty_legacy.Very Low', 'plus.attack_difficulty_subsequent.High', 'plus.attack_difficulty_subsequent.Low', 'plus.attack_difficulty_subsequent.Moderate', 'plus.attack_difficulty_subsequent.NA', 'plus.attack_difficulty_subsequent.Other', 'plus.attack_difficulty_subsequent.Unknown', 'plus.attack_difficulty_subsequent.Very Low', 'plus.attribute.confidentiality.credit_monitoring_years', 'plus.attribute.confidentiality.credit_monitoring.No', 'plus.attribute.confidentiality.credit_monitoring.Other', 'plus.attribute.confidentiality.credit_monitoring.Unknown', 'plus.attribute.confidentiality.credit_monitoring.Yes', 'plus.attribute.confidentiality.data_abuse.No', 'plus.attribute.confidentiality.data_abuse.Other', 'plus.attribute.confidentiality.data_abuse.Unknown', 'plus.attribute.confidentiality.data_abuse.Yes', 'plus.attribute.confidentiality.partner_data.No', 'plus.attribute.confidentiality.partner_data.Other', 'plus.attribute.confidentiality.partner_data.Unknown', 'plus.attribute.confidentiality.partner_data.Yes', 'plus.attribute.confidentiality.partner_number', 'plus.control_inadequacies_legacy', 'plus.created', 'plus.dbir_year', 'plus.github', 'plus.investigator', 'plus.master_id', 'plus.modified', 'plus.pci.compliance_status.Found Compliant', 'plus.pci.compliance_status.Not Compliant', 'plus.pci.compliance_status.Unknown', 'plus.pci.merchant_level.Level 1', 'plus.pci.merchant_level.Level 2', 'plus.pci.merchant_level.Level 3', 'plus.pci.merchant_level.Level 4', 'plus.pci.merchant_level.Unknown', 'plus.pci.notes', 'plus.pci.req_1.In Place', 'plus.pci.req_1.Not Applicable', 'plus.pci.req_1.Not In Place', 'plus.pci.req_1.Unknown', 'plus.pci.req_10.In Place', 'plus.pci.req_10.Not Applicable', 'plus.pci.req_10.Not In Place', 'plus.pci.req_10.Unknown', 'plus.pci.req_11.In Place', 'plus.pci.req_11.Not Applicable', 'plus.pci.req_11.Not In Place', 'plus.pci.req_11.Unknown', 'plus.pci.req_12.In Place', 'plus.pci.req_12.Not Applicable', 'plus.pci.req_12.Not In Place', 'plus.pci.req_12.Unknown', 'plus.pci.req_2.In Place', 'plus.pci.req_2.Not Applicable', 'plus.pci.req_2.Not In Place', 'plus.pci.req_2.Unknown', 'plus.pci.req_3.In Place', 'plus.pci.req_3.Not Applicable', 'plus.pci.req_3.Not In Place', 'plus.pci.req_3.Unknown', 'plus.pci.req_4.In Place', 'plus.pci.req_4.Not Applicable', 'plus.pci.req_4.Not In Place', 'plus.pci.req_4.Unknown', 'plus.pci.req_5.In Place', 'plus.pci.req_5.Not Applicable', 'plus.pci.req_5.Not In Place', 'plus.pci.req_5.Unknown', 'plus.pci.req_6.In Place', 'plus.pci.req_6.Not Applicable', 'plus.pci.req_6.Not In Place', 'plus.pci.req_6.Unknown', 'plus.pci.req_7.In Place', 'plus.pci.req_7.Not Applicable', 'plus.pci.req_7.Not In Place', 'plus.pci.req_7.Unknown', 'plus.pci.req_8.In Place', 'plus.pci.req_8.Not Applicable', 'plus.pci.req_8.Not In Place', 'plus.pci.req_8.Unknown', 'plus.pci.req_9.In Place', 'plus.pci.req_9.Not Applicable', 'plus.pci.req_9.Not In Place', 'plus.pci.req_9.Unknown', 'plus.pci.status_determined', 'plus.row_number', 'plus.security_maturity.Defined', 'plus.security_maturity.Initial', 'plus.security_maturity.Managed', 'plus.security_maturity.Measured', 'plus.security_maturity.Optimizing', 'plus.security_maturity.Unknown', 'plus.sub_source', 'plus.timeline.notification.day', 'plus.timeline.notification.month', 'plus.timeline.notification.year', 'plus.unfollowed_policies.No', 'plus.unfollowed_polici ...
# <bound method DataFrame.count of DataFrame[action.environmental.notes: string, action.environmental.variety.Deterioration: string, action.environmental.variety.Earthquake: string, action.environmental.variety.EMI: string, action.environmental.variety.ESD: string, action.environmental.variety.Fire: string, action.environmental.variety.Flood: string, action.environmental.variety.Hazmat: string, action.environmental.variety.Humidity: string, action.environmental.variety.Hurricane: string, action.environmental.variety.Ice: string, action.environmental.variety.Landslide: string, action.environmental.variety.Leak: string, action.environmental.variety.Lightning: string, action.environmental.variety.Meteorite: string, action.environmental.variety.Other: string, action.environmental.variety.Particulates: string, action.environmental.variety.Pathogen: string, action.environmental.variety.Power failure: string, action.environmental.variety.Temperature: string, action.environmental.variety.Tornado: string, action.environmental.variety.Tsunami: string, action.environmental.variety.Unknown: string, action.environmental.variety.Vermin: string, action.environmental.variety.Volcano: string, action.environmental.variety.Wind: string, action.error.notes: string, action.error.variety.Capacity shortage: string, action.error.variety.Classification error: string, action.error.variety.Data entry error: string, action.error.variety.Disposal error: string, action.error.variety.Gaffe: string, action.error.variety.Loss: string, action.error.variety.Maintenance error: string, action.error.variety.Malfunction: string, action.error.variety.Misconfiguration: string, action.error.variety.Misdelivery: string, action.error.variety.Misinformation: string, action.error.variety.Omission: string, action.error.variety.Other: string, action.error.variety.Physical accidents: string, action.error.variety.Programming error: string, action.error.variety.Publishing error: string, action.error.variety.Unknown: string, action.error.vector.Carelessness: string, action.error.vector.Inadequate personnel: string, action.error.vector.Inadequate processes: string, action.error.vector.Inadequate technology: string, action.error.vector.Other: string, action.error.vector.Random error: string, action.error.vector.Unknown: string, action.error.vector.Web application: string, action.hacking.cve: string, action.hacking.notes: string, action.hacking.result.Deploy payload: string, action.hacking.result.Elevate: string, action.hacking.result.Exfiltrate: string, action.hacking.result.Infiltrate: string, action.hacking.result.Lateral movement: string, action.hacking.result.NA: string, action.hacking.result.Other: string, action.hacking.result.Unknown: string, action.hacking.variety.Abuse of functionality: string, action.hacking.variety.Backdoor: string, action.hacking.variety.Brute force: string, action.hacking.variety.Buffer overflow: string, action.hacking.variety.Cache poisoning: string, action.hacking.variety.Cryptanalysis: string, action.hacking.variety.CSRF: string, action.hacking.variety.Disable controls: string, action.hacking.variety.DoS: string, action.hacking.variety.Evade Defenses: string, action.hacking.variety.Exploit misconfig: string, action.hacking.variety.Exploit vuln: string, action.hacking.variety.Forced browsing: string, action.hacking.variety.Format string attack: string, action.hacking.variety.Fuzz testing: string, action.hacking.variety.HTTP request smuggling: string, action.hacking.variety.HTTP request splitting: string, action.hacking.variety.HTTP response smuggling: string, action.hacking.variety.HTTP response splitting: string, action.hacking.variety.Insecure deserialization: string, action.hacking.variety.Integer overflows: string, action.hacking.variety.LDAP injection: string, action.hacking.variety.Mail command injection: string, action.hacking.variety.MitM: string, action.hacking.variety.Null byte injection: string, action.hacking.variety.Offline cracking: str ...

# %% [markdown]
# ## Part 2: Renaming the Columns
# You may have noted that the column names contain special characters such as '.' and white space ' '. Your task to replace the column names using the following rule:
# ```
# '.' -> '-'  (minus sign)
# ' ' -> '_'  (underscore sign)
# ```
#
# For this you may find the `toDF` function useful:
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.DataFrame.toDF.html
#
# Set the renamed DataFrame result to `df`, overwriting the previous variable.

# %%
# Your code for Part 2 goes here.

columns = df.columns

new_col = []

for i in columns:
    chk = i.replace(' ', '_').replace('.', '_')
    new_col.append(chk)
print(new_col)

for i in range(len(df.columns)):
    df = df.withColumnRenamed(df.columns[i], new_col[i])
# Out:
# ['action_environmental_notes', 'action_environmental_variety_Deterioration', 'action_environmental_variety_Earthquake', 'action_environmental_variety_EMI', 'action_environmental_variety_ESD', 'action_environmental_variety_Fire', 'action_environmental_variety_Flood', 'action_environmental_variety_Hazmat', 'action_environmental_variety_Humidity', 'action_environmental_variety_Hurricane', 'action_environmental_variety_Ice', 'action_environmental_variety_Landslide', 'action_environmental_variety_Leak', 'action_environmental_variety_Lightning', 'action_environmental_variety_Meteorite', 'action_environmental_variety_Other', 'action_environmental_variety_Particulates', 'action_environmental_variety_Pathogen', 'action_environmental_variety_Power_failure', 'action_environmental_variety_Temperature', 'action_environmental_variety_Tornado', 'action_environmental_variety_Tsunami', 'action_environmental_variety_Unknown', 'action_environmental_variety_Vermin', 'action_environmental_variety_Volcano', 'action_environmental_variety_Wind', 'action_error_notes', 'action_error_variety_Capacity_shortage', 'action_error_variety_Classification_error', 'action_error_variety_Data_entry_error', 'action_error_variety_Disposal_error', 'action_error_variety_Gaffe', 'action_error_variety_Loss', 'action_error_variety_Maintenance_error', 'action_error_variety_Malfunction', 'action_error_variety_Misconfiguration', 'action_error_variety_Misdelivery', 'action_error_variety_Misinformation', 'action_error_variety_Omission', 'action_error_variety_Other', 'action_error_variety_Physical_accidents', 'action_error_variety_Programming_error', 'action_error_variety_Publishing_error', 'action_error_variety_Unknown', 'action_error_vector_Carelessness', 'action_error_vector_Inadequate_personnel', 'action_error_vector_Inadequate_processes', 'action_error_vector_Inadequate_technology', 'action_error_vector_Other', 'action_error_vector_Random_error', 'action_error_vector_Unknown', 'action_error_vector_Web_application', 'action_hacking_cve', 'action_hacking_notes', 'action_hacking_result_Deploy_payload', 'action_hacking_result_Elevate', 'action_hacking_result_Exfiltrate', 'action_hacking_result_Infiltrate', 'action_hacking_result_Lateral_movement', 'action_hacking_result_NA', 'action_hacking_result_Other', 'action_hacking_result_Unknown', 'action_hacking_variety_Abuse_of_functionality', 'action_hacking_variety_Backdoor', 'action_hacking_variety_Brute_force', 'action_hacking_variety_Buffer_overflow', 'action_hacking_variety_Cache_poisoning', 'action_hacking_variety_Cryptanalysis', 'action_hacking_variety_CSRF', 'action_hacking_variety_Disable_controls', 'action_hacking_variety_DoS', 'action_hacking_variety_Evade_Defenses', 'action_hacking_variety_Exploit_misconfig', 'action_hacking_variety_Exploit_vuln', 'action_hacking_variety_Forced_browsing', 'action_hacking_variety_Format_string_attack', 'action_hacking_variety_Fuzz_testing', 'action_hacking_variety_HTTP_request_smuggling', 'action_hacking_variety_HTTP_request_splitting', 'action_hacking_variety_HTTP_response_smuggling', 'action_hacking_variety_HTTP_response_splitting', 'action_hacking_variety_Insecure_deserialization', 'action_hacking_variety_Integer_overflows', 'action_hacking_variety_LDAP_injection', 'action_hacking_variety_Mail_command_injection', 'action_hacking_variety_MitM', 'action_hacking_variety_Null_byte_injection', 'action_hacking_variety_Offline_cracking', 'action_hacking_variety_OS_commanding', 'action_hacking_variety_Other', 'action_hacking_variety_Pass-the-hash', 'action_hacking_variety_Path_traversal', 'action_hacking_variety_Profile_host', 'action_hacking_variety_Reverse_engineering', 'action_hacking_variety_RFI', 'action_hacking_variety_Routing_detour', 'action_hacking_variety_Scan_network', 'action_hacking_variety_Session_fixation', 'action_hacking_variety_Session_prediction', 'action_hacking_variety_Session_replay', 'action_hacking_variety_Soap_array_abuse', 'action_hacking_variety_Special_element_injec ...
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# OS', 'plus_asset_os_Windows', 'plus_asset_os_Windows_Phone', 'plus_asset_total', 'plus_attack_difficulty_initial_High', 'plus_attack_difficulty_initial_Low', 'plus_attack_difficulty_initial_Moderate', 'plus_attack_difficulty_initial_NA', 'plus_attack_difficulty_initial_Other', 'plus_attack_difficulty_initial_Unknown', 'plus_attack_difficulty_initial_Very_Low', 'plus_attack_difficulty_legacy_High', 'plus_attack_difficulty_legacy_Low', 'plus_attack_difficulty_legacy_Moderate', 'plus_attack_difficulty_legacy_NA', 'plus_attack_difficulty_legacy_Other', 'plus_attack_difficulty_legacy_Unknown', 'plus_attack_difficulty_legacy_Very_Low', 'plus_attack_difficulty_subsequent_High', 'plus_attack_difficulty_subsequent_Low', 'plus_attack_difficulty_subsequent_Moderate', 'plus_attack_difficulty_subsequent_NA', 'plus_attack_difficulty_subsequent_Other', 'plus_attack_difficulty_subsequent_Unknown', 'plus_attack_difficulty_subsequent_Very_Low', 'plus_attribute_confidentiality_credit_monitoring_years', 'plus_attribute_confidentiality_credit_monitoring_No', 'plus_attribute_confidentiality_credit_monitoring_Other', 'plus_attribute_confidentiality_credit_monitoring_Unknown', 'plus_attribute_confidentiality_credit_monitoring_Yes', 'plus_attribute_confidentiality_data_abuse_No', 'plus_attribute_confidentiality_data_abuse_Other', 'plus_attribute_confidentiality_data_abuse_Unknown', 'plus_attribute_confidentiality_data_abuse_Yes', 'plus_attribute_confidentiality_partner_data_No', 'plus_attribute_confidentiality_partner_data_Other', 'plus_attribute_confidentiality_partner_data_Unknown', 'plus_attribute_confidentiality_partner_data_Yes', 'plus_attribute_confidentiality_partner_number', 'plus_control_inadequacies_legacy', 'plus_created', 'plus_dbir_year', 'plus_github', 'plus_investigator', 'plus_master_id', 'plus_modified', 'plus_pci_compliance_status_Found_Compliant', 'plus_pci_compliance_status_Not_Compliant', 'plus_pci_compliance_status_Unknown', 'plus_pci_merchant_level_Level_1', 'plus_pci_merchant_level_Level_2', 'plus_pci_merchant_level_Level_3', 'plus_pci_merchant_level_Level_4', 'plus_pci_merchant_level_Unknown', 'plus_pci_notes', 'plus_pci_req_1_In_Place', 'plus_pci_req_1_Not_Applicable', 'plus_pci_req_1_Not_In_Place', 'plus_pci_req_1_Unknown', 'plus_pci_req_10_In_Place', 'plus_pci_req_10_Not_Applicable', 'plus_pci_req_10_Not_In_Place', 'plus_pci_req_10_Unknown', 'plus_pci_req_11_In_Place', 'plus_pci_req_11_Not_Applicable', 'plus_pci_req_11_Not_In_Place', 'plus_pci_req_11_Unknown', 'plus_pci_req_12_In_Place', 'plus_pci_req_12_Not_Applicable', 'plus_pci_req_12_Not_In_Place', 'plus_pci_req_12_Unknown', 'plus_pci_req_2_In_Place', 'plus_pci_req_2_Not_Applicable', 'plus_pci_req_2_Not_In_Place', 'plus_pci_req_2_Unknown', 'plus_pci_req_3_In_Place', 'plus_pci_req_3_Not_Applicable', 'plus_pci_req_3_Not_In_Place', 'plus_pci_req_3_Unknown', 'plus_pci_req_4_In_Place', 'plus_pci_req_4_Not_Applicable', 'plus_pci_req_4_Not_In_Place', 'plus_pci_req_4_Unknown', 'plus_pci_req_5_In_Place', 'plus_pci_req_5_Not_Applicable', 'plus_pci_req_5_Not_In_Place', 'plus_pci_req_5_Unknown', 'plus_pci_req_6_In_Place', 'plus_pci_req_6_Not_Applicable', 'plus_pci_req_6_Not_In_Place', 'plus_pci_req_6_Unknown', 'plus_pci_req_7_In_Place', 'plus_pci_req_7_Not_Applicable', 'plus_pci_req_7_Not_In_Place', 'plus_pci_req_7_Unknown', 'plus_pci_req_8_In_Place', 'plus_pci_req_8_Not_Applicable', 'plus_pci_req_8_Not_In_Place', 'plus_pci_req_8_Unknown', 'plus_pci_req_9_In_Place', 'plus_pci_req_9_Not_Applicable', 'plus_pci_req_9_Not_In_Place', 'plus_pci_req_9_Unknown', 'plus_pci_status_determined', 'plus_row_number', 'plus_security_maturity_Defined', 'plus_security_maturity_Initial', 'plus_security_maturity_Managed', 'plus_security_maturity_Measured', 'plus_security_maturity_Optimizing', 'plus_security_maturity_Unknown', 'plus_sub_source', 'plus_timeline_notification_day', 'plus_timeline_notification_month', 'plus_timeline_notification_year', 'plus_unfollowed_policies_No', 'plus_unfollowed_polici ...

# %% [markdown]
# ### Interlude
# The dataset contains security incidents from all over the world. Let us restrict our focus to those whose primary location of the business group is in the U.S. We will also only look at attacks that are related to *hacking.* This is implemented for you below.

# %%
# DO NOT MODIFY THIS CODE.

# Restrict ourselves to attacks whose primary location of the business group is in the US.
df = df.filter(df["`victim-country-US`"].rlike("(?i)^*TRUE$"))
print("Attacks in US: %d rows." % df.count())
df = df.select(df.colRegex("`.+hacking[-]{1}variety.+`"), df.colRegex("`timeline[-]{1}incident[-]{1}year`"))
print("After filting to U.S. location, there are %d rows." % df.count())
# Out:
# Attacks in US: 5860 rows.
# After filting to U.S. location, there are 5860 rows.

# %%
# DO NOT REMOVE: This will show the first row.
df.take(1)
# Out:
# [Row(action.environmental.notes='NA', action.environmental.variety.Deterioration='FALSE', action.environmental.variety.Earthquake='FALSE', action.environmental.variety.EMI='FALSE', action.environmental.variety.ESD='FALSE', action.environmental.variety.Fire='FALSE', action.environmental.variety.Flood='FALSE', action.environmental.variety.Hazmat='FALSE', action.environmental.variety.Humidity='FALSE', action.environmental.variety.Hurricane='FALSE', action.environmental.variety.Ice='FALSE', action.environmental.variety.Landslide='FALSE', action.environmental.variety.Leak='FALSE', action.environmental.variety.Lightning='FALSE', action.environmental.variety.Meteorite='FALSE', action.environmental.variety.Other='FALSE', action.environmental.variety.Particulates='FALSE', action.environmental.variety.Pathogen='FALSE', action.environmental.variety.Power failure='FALSE', action.environmental.variety.Temperature='FALSE', action.environmental.variety.Tornado='FALSE', action.environmental.variety.Tsunami='FALSE', action.environmental.variety.Unknown='FALSE', action.environmental.variety.Vermin='FALSE', action.environmental.variety.Volcano='FALSE', action.environmental.variety.Wind='FALSE', action.error.notes='NA', action.error.variety.Capacity shortage='FALSE', action.error.variety.Classification error='FALSE', action.error.variety.Data entry error='FALSE', action.error.variety.Disposal error='FALSE', action.error.variety.Gaffe='FALSE', action.error.variety.Loss='FALSE', action.error.variety.Maintenance error='FALSE', action.error.variety.Malfunction='FALSE', action.error.variety.Misconfiguration='FALSE', action.error.variety.Misdelivery='FALSE', action.error.variety.Misinformation='FALSE', action.error.variety.Omission='FALSE', action.error.variety.Other='FALSE', action.error.variety.Physical accidents='FALSE', action.error.variety.Programming error='FALSE', action.error.variety.Publishing error='FALSE', action.error.variety.Unknown='FALSE', action.error.vector.Carelessness='FALSE', action.error.vector.Inadequate personnel='FALSE', action.error.vector.Inadequate processes='FALSE', action.error.vector.Inadequate technology='FALSE', action.error.vector.Other='FALSE', action.error.vector.Random error='FALSE', action.error.vector.Unknown='FALSE', action.error.vector.Web application='FALSE', action.hacking.cve='NA', action.hacking.notes='NA', action.hacking.result.Deploy payload='FALSE', action.hacking.result.Elevate='FALSE', action.hacking.result.Exfiltrate='FALSE', action.hacking.result.Infiltrate='FALSE', action.hacking.result.Lateral movement='FALSE', action.hacking.result.NA='FALSE', action.hacking.result.Other='FALSE', action.hacking.result.Unknown='FALSE', action.hacking.variety.Abuse of functionality='FALSE', action.hacking.variety.Backdoor='FALSE', action.hacking.variety.Brute force='FALSE', action.hacking.variety.Buffer overflow='FALSE', action.hacking.variety.Cache poisoning='FALSE', action.hacking.variety.Cryptanalysis='FALSE', action.hacking.variety.CSRF='FALSE', action.hacking.variety.Disable controls='FALSE', action.hacking.variety.DoS='FALSE', action.hacking.variety.Evade Defenses='FALSE', action.hacking.variety.Exploit misconfig='FALSE', action.hacking.variety.Exploit vuln='FALSE', action.hacking.variety.Forced browsing='FALSE', action.hacking.variety.Format string attack='FALSE', action.hacking.variety.Fuzz testing='FALSE', action.hacking.variety.HTTP request smuggling='FALSE', action.hacking.variety.HTTP request splitting='FALSE', action.hacking.variety.HTTP response smuggling='FALSE', action.hacking.variety.HTTP response splitting='FALSE', action.hacking.variety.Insecure deserialization='FALSE', action.hacking.variety.Integer overflows='FALSE', action.hacking.variety.LDAP injection='FALSE', action.hacking.variety.Mail command injection='FALSE', action.hacking.variety.MitM='FALSE', action.hacking.variety.Null byte injection='FALSE', action.hacking.variety.Offline cracking='FALSE', action.hacking.variety.OS commanding='FALSE', ...

# %% [markdown]
# ### Interlude 2
# As you have seen above, the format of the data is unique since each column is essentially a boolean flag denoting whether an incident is of that particular type. For example, if `action-hacking-variety-Abuse_of_functionality` has the value `TRUE` (in all caps string), then the incident corresponding to the row is of the type. Of course, each incident can belong to more than one hacking type (it could also be a backdoor attempt, etc.).
#
# What may be useful here is somehow to create a single column that captures all of the columns that have `TRUE` value so that it can be expanded into multiple rows. For example, if an incident is of type `"backdoor", "bruteforce", "buffer_overflow"`, then a Python list `["backdoor", "bruteforce", "buffer_overflow"]` is created.
#
# There are many ways of achieving this effect and one way is to utilize the UDF functionality. This is shown below.
#
# Note that `df_result` will contain two columns, the first is the `year` which denotes the time of the security incident and the second is the `hacking_types` which will essentially contain a Python list of hacking types that correspond to the incident.

# %%
# DO NOT MODIFY.
from pyspark.sql.functions import udf
from pyspark.sql.types import ArrayType, StringType
import pyspark.sql.functions as F
broadcast_column_names = sc.broadcast(df.columns)
def process_row(row):    
    hacking_types = []
    for i, column_name in enumerate(broadcast_column_names.value):
        if "action" in column_name and row[column_name] == 'TRUE':
            hacking_types += [ column_name ]
    return hacking_types

udf_func = udf(lambda row : process_row(row), ArrayType(StringType(), True))

# This is the DataFrame that should be used in Part 3.
df_result = df.select(F.col("timeline-incident-year").alias("year"), udf_func(F.struct(*list(df.columns))).alias("hacking_types"))
df_result = df_result.filter(F.size(df_result.hacking_types) > 0)

# %%
# DO NOT REMOVE: This will show the few rows.
df_result.orderBy("year").tail(50)
# Out:
# [Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='NA'),
#  Row(year='TRUE'),
#  Row(year='TRUE'),
#  Row(year='TRUE')]

# %% [markdown]
# ## Part 3
# Your final step is to perform `flatMap` operation on `hacking_types` column of `df_result`.
# For example, if a row in `df_result` has the following values:
# `{year: 2010, hacking_types: [backdoor, bruteforce, buffer_overflow]}`
# then the following three records will be created:
# ```
# {year: 2010, type: backdoor }
# {year: 2010, type: bruteforce }
# {year: 2010, type: buffer_overflow }
# ```
# For this you can utilize:
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.functions.explode.html
#
# For a better example:
# https://sparkbyexamples.com/pyspark/pyspark-flatmap-transformation/

# %%
# Your code for Part 3 goes here.
from pyspark.sql.functions import explode
df_result = df_result.rdd.flatMap(lambda row: [(row['year'], hacking_type) for hacking_type in row['hacking_types']]).toDF(['year', 'type'])

# %% [markdown]
# ### Conclusion
# If you have correctly finished Part 3, you will see an output below. The next logical step maybe is to do a group-level analysis on different types of hacking, etc. but this is beyond the scope of this assignment.

# %%
# DO NOT REMOVE.
df_result.tail(10)
